# %%
import pandas as pd
merged = pd.read_csv('mergecvd.csv')
cvd = pd.read_csv('cardio.csv')
heart = pd.read_csv('Heart.csv')

# %%
print('merged',merged.shape)
print('cvd',cvd.shape)
print('Heart',heart.shape)
# Out:
# merged (1918, 12)
# cvd (1000, 14)
# Heart (918, 12)

# %%
merged.tail()
# Out:
#       Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 1913   48   M           NAP        139          349          0        LVH
# 1914   47   M           ASY        143          258          1         ST
# 1915   69   M            TA        156          434          1     Normal
# 1916   45   M           ATA        186          417          0         ST
# 1917   25   M            TA        158          270          0     Normal
#
#       MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 1913    183              Y      5.6     Flat             1
# 1914     98              Y      5.7       Up             0
# 1915    196              N      1.4     Down             1
# 1916    117              Y      5.9     Down             1
# 1917    143              Y      4.7      NaN             0

# %%
X = merged.drop('HeartDisease',axis=1)
y = merged['HeartDisease']

print(f'\nShape of X {X.shape} , Shape of y {y.shape}\n')
# Out:
# Shape of X (1918, 11) , Shape of y (1918,)

# %%
# Outlier Detection
# Age is fineminimum is 28 and maximum is 77
# RESTING BP < 40 AND RESTING BP > 250 ARE CONSIDERED AS OUTLIER
# Cholesterol < 100 or Cholesterol > 400 → treated as outlier
# Fasting BS are binary 0 and 1
# Max HR are fine betwen 60 - 202
# Oldpeak < 0 or Oldpeak > 6 → Outlier/Invalid

# Counting the code for Domain Knowledge 
# Resting BP outlier
outlier_restingBP = X[(X['RestingBP'] < 40) | (X['RestingBP'] > 250)]
# Cholestrol outliers
outlier_chol = X[(X['Cholesterol'] < 100 ) | (X['Cholesterol'] > 400) ]
# Oldpeak outlier
outlier_oldpeak = X[(X['Oldpeak'] < 0 ) | (X['Oldpeak'] > 6 )]

# Count total outlier
print("RestingBP outliers:",len(outlier_restingBP))
print("Cholesterol outliers:",len(outlier_chol))
print("Oldpeak outliers:",len(outlier_oldpeak))
# outlier_chol.head()
# Out:
# RestingBP outliers: 1
# Cholesterol outliers: 507
# Oldpeak outliers: 27

# %%
cvd.tail()
# Out:
#      patientid  age  gender  chestpain  restingBP  serumcholestrol  \
# 995    9949544   48       1          2        139              349
# 996    9953423   47       1          3        143              258
# 997    9965859   69       1          0        156              434
# 998    9988507   45       1          1        186              417
# 999    9990855   25       1          0        158              270
#
#      fastingbloodsugar  restingrelectro  maxheartrate  exerciseangia  oldpeak  \
# 995                  0                2           183              1      5.6
# 996                  1                1            98              1      5.7
# 997                  1                0           196              0      1.4
# 998                  0                1           117              1      5.9
# 999                  0                0           143              1      4.7
#
#      slope  noofmajorvessels  target
# 995      2                 2       1
# ...

# %%
heart.tail()
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 913    132              N      1.2     Flat             1
# 914    141              N      3.4     Flat             1
# 915    115              Y      1.2     Flat             1
# 916    174              N      0.0     Flat             1
# 917    173              N      0.0       Up             0

# %%
print('merged',merged.columns)
print('cvd',cvd.columns)
print('heart',heart.columns)
# Out:
# merged Index(['Age', 'Sex', 'ChestPainType', 'RestingBP', 'Cholesterol', 'FastingBS',
#        'RestingECG', 'MaxHR', 'ExerciseAngina', 'Oldpeak', 'ST_Slope',
#        'HeartDisease'],
#       dtype='object')
# cvd Index(['patientid', 'age', 'gender', 'chestpain', 'restingBP',
#        'serumcholestrol', 'fastingbloodsugar', 'restingrelectro',
#        'maxheartrate', 'exerciseangia', 'oldpeak', 'slope', 'noofmajorvessels',
#        'target'],
#       dtype='object')
# heart Index(['Age', 'Sex', 'ChestPainType', 'RestingBP', 'Cholesterol', 'FastingBS',
#        'RestingECG', 'MaxHR', 'ExerciseAngina', 'Oldpeak', 'ST_Slope',
#        'HeartDisease'],
#       dtype='object')

# %%
merged.describe()
# Out:
#                Age    RestingBP  Cholesterol    FastingBS        MaxHR  \
# count  1918.000000  1918.000000  1918.000000  1918.000000  1918.000000
# mean     51.285193   142.485401   257.531283     0.265902   141.328467
# std      14.609167    26.932915   134.286677     0.441928    30.627152
# min      20.000000     0.000000     0.000000     0.000000    60.000000
# 25%      41.000000   124.000000   197.250000     0.000000   120.000000
# 50%      53.000000   138.000000   256.000000     0.000000   141.000000
# 75%      62.000000   160.000000   337.000000     1.000000   165.000000
# max      80.000000   200.000000   603.000000     1.000000   202.000000
#
#            Oldpeak  HeartDisease
# count  1918.000000   1918.000000
# mean      1.836444      0.567258
# std       1.707201      0.495585
# min      -2.600000      0.000000
# 25%       0.300000      0.000000
# 50%       1.500000      1.000000
# 75%       2.900000      1.000000
# max       6.200000      1.000000

# %%
cvd.describe()
# Out:
#           patientid         age       gender    chestpain    restingBP  \
# count  1.000000e+03  1000.00000  1000.000000  1000.000000  1000.000000
# mean   5.048704e+06    49.24200     0.765000     0.980000   151.747000
# std    2.895905e+06    17.86473     0.424211     0.953157    29.965228
# min    1.033680e+05    20.00000     0.000000     0.000000    94.000000
# 25%    2.536440e+06    34.00000     1.000000     0.000000   129.000000
# 50%    4.952508e+06    49.00000     1.000000     1.000000   147.000000
# 75%    7.681877e+06    64.25000     1.000000     2.000000   181.000000
# max    9.990855e+06    80.00000     1.000000     3.000000   200.000000
#
#        serumcholestrol  fastingbloodsugar  restingrelectro  maxheartrate  \
# count      1000.000000        1000.000000      1000.000000   1000.000000
# mean        311.447000           0.296000         0.748000    145.477000
# std         132.443801           0.456719         0.770123     34.190268
# ...

# %%
heart.describe()
# Out:
#               Age   RestingBP  Cholesterol   FastingBS       MaxHR  \
# count  918.000000  918.000000   918.000000  918.000000  918.000000
# mean    53.510893  132.396514   198.799564    0.233115  136.809368
# std      9.432617   18.514154   109.384145    0.423046   25.460334
# min     28.000000    0.000000     0.000000    0.000000   60.000000
# 25%     47.000000  120.000000   173.250000    0.000000  120.000000
# 50%     54.000000  130.000000   223.000000    0.000000  138.000000
# 75%     60.000000  140.000000   267.000000    0.000000  156.000000
# max     77.000000  200.000000   603.000000    1.000000  202.000000
#
#           Oldpeak  HeartDisease
# count  918.000000    918.000000
# mean     0.887364      0.553377
# std      1.066570      0.497414
# min     -2.600000      0.000000
# 25%      0.000000      0.000000
# 50%      0.600000      1.000000
# 75%      1.500000      1.000000
# max      6.200000      1.000000

# %%
print('merged',merged.columns)
# Out:
# merged Index(['Age', 'Sex', 'ChestPainType', 'RestingBP', 'Cholesterol', 'FastingBS',
#        'RestingECG', 'MaxHR', 'ExerciseAngina', 'Oldpeak', 'ST_Slope',
#        'HeartDisease'],
#       dtype='object')

# %%
cvd.isna().sum()
# Out:
# patientid            0
# age                  0
# gender               0
# chestpain            0
# restingBP            0
# serumcholestrol      0
# fastingbloodsugar    0
# restingrelectro      0
# maxheartrate         0
# exerciseangia        0
# oldpeak              0
# slope                0
# noofmajorvessels     0
# target               0
# dtype: int64

# %%
cvd.duplicated().sum()
# Out:
# np.int64(0)

# %%
merged.duplicated(subset=['Age', 'Sex','ChestPainType', 'RestingBP', 'Cholesterol','FastingBS','ExerciseAngina','MaxHR', 'Oldpeak','ST_Slope','HeartDisease' ]).sum()
# Out:
# np.int64(1)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df['HeartDisease'].value_counts()
# Out:
# HeartDisease
# 1    1088
# 0     830
# Name: count, dtype: int64

# %%
df.columns
# Out:
# Index(['Age', 'Sex', 'ChestPainType', 'RestingBP', 'Cholesterol', 'FastingBS',
#        'RestingECG', 'MaxHR', 'ExerciseAngina', 'Oldpeak', 'ST_Slope',
#        'HeartDisease'],
#       dtype='object')

# %%
data.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %%
df.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %%
merged = pd.read_csv('mergedcvd.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 merged = pd.read_csv('mergedcvd.csv')
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
# ...

# %%
print(df.columns)
print(data.columns)
# Out:
# Index(['Age', 'Sex', 'ChestPainType', 'RestingBP', 'Cholesterol', 'FastingBS',
#        'RestingECG', 'MaxHR', 'ExerciseAngina', 'Oldpeak', 'ST_Slope',
#        'HeartDisease'],
#       dtype='object')
# Index(['Age', 'Sex', 'ChestPainType', 'RestingBP', 'Cholesterol', 'FastingBS',
#        'RestingECG', 'MaxHR', 'ExerciseAngina', 'Oldpeak', 'ST_Slope',
#        'HeartDisease'],
#       dtype='object')
